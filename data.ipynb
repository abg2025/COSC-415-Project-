# %%
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import StepLR
from torchvision.datasets import ImageFolder
from torchvision.transforms import Resize, Grayscale
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import numpy as np


class Net(nn.Module):
    def __init__(self, in_channels):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, 32, 3, padding=1)  # Increased filters and added padding
        self.conv2 = nn.Conv2d(32, 64, 3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, 3, padding=1)  # Additional conv layer
        self.pool = nn.MaxPool2d(2, 2)
        self.dropout1 = nn.Dropout(0.25)
        self.dropout2 = nn.Dropout(0.5)
        self.fc1 = nn.Linear(80000, 512)  # Adjusted to new flattening size and more neurons
        self.fc2 = nn.Linear(512, 128)
        self.fc3 = nn.Linear(128, 29)  # Additional layer

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        x = F.relu(self.conv3(x))
        x = self.pool(x)
        x = self.dropout1(x)
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = self.dropout2(x)
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        output = F.log_softmax(x, dim=1)
        return output


def train(args, model, device, train_loader, optimizer, epoch):
    model.train()
    correct = 0
    total = 0
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()

        # Calculate accuracy
        pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
        correct += pred.eq(target.view_as(pred)).sum().item()
        total += target.size(0)

        if batch_idx % args['log_interval'] == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}\tAccuracy: {:.2f}%'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item(), 100. * correct / total))
            
            # Optional: break after one pass over the data if dry-run is enabled
            if args['dry_run']:
                break

    # Print overall accuracy at the end of the epoch
    print('Epoch: {} Training Accuracy: {:.2f}%'.format(epoch, 100. * correct / total))



def test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()  # sum up batch loss

            # Output tensor check
            
            pred = output.argmax(dim=1)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
            total += target.size(0)


    test_loss /= len(test_loader.dataset)
    accuracy = 100. * correct / len(test_loader.dataset)
    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset), accuracy))

def evaluate_model(model, device, test_loader):
    model.eval()  # Set the model to evaluation mode
    all_preds = []
    all_targets = []

    with torch.no_grad():  # Turn off gradients for evaluation, saves memory and computations
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)  # Move data to the appropriate device
            output = model(data)  # Get model output
            _, preds = torch.max(output, 1)  # Get the index of the max log-probability, which are our predictions

            all_preds.extend(preds.cpu().numpy())  # Store predictions
            all_targets.extend(target.cpu().numpy())  # Store true labels

    return all_targets, all_preds
    

# Assuming you have a test_loader and a device setup

def plot_confusion_matrix(all_targets, all_preds, class_to_idx):
    conf_matrix = confusion_matrix(all_targets, all_preds)
    plt.figure(figsize=(12, 10))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
                xticklabels=[class_to_idx[i] for i in range(len(class_to_idx))],
                yticklabels=[class_to_idx[i] for i in range(len(class_to_idx))])
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')
    plt.show()
    
    # Analyze the confusion matrix to find most frequently missed letters
    missed_counts = np.sum(conf_matrix, axis=1) - np.diag(conf_matrix)
    most_missed_index = np.argmax(missed_counts)
    most_missed_letter = index_to_letter[most_missed_index]
    print(f'Most frequently missed letter: {most_missed_letter} (Index: {most_missed_index}) with {missed_counts[most_missed_index]} misses')

def final_evaluation(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    all_preds = []
    all_targets = []
    
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()
            all_preds.extend(pred.view_as(target).cpu().numpy())
            all_targets.extend(target.cpu().numpy())

    # Metrics Calculation
    test_loss /= len(test_loader.dataset)
    accuracy = 100. * correct / len(test_loader.dataset)
    precision = precision_score(all_targets, all_preds, average='macro')
    recall = recall_score(all_targets, all_preds, average='macro')
    f1 = f1_score(all_targets, all_preds, average='macro')
    
   
    print(f'\nFinal Evaluation: Loss: {test_loss:.4f}, Accuracy: {accuracy:.2f}%, Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1:.4f}')
    


def load_data(train_kwargs, test_kwargs, check):
    normal_transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.RandomHorizontalFlip(),     
        transforms.Normalize((0.5187, 0.4988, 0.5141), (0.2281, 0.2557, 0.2630))
        ])
    horizontal_transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.RandomHorizontalFlip(),     
        transforms.Normalize((0.5187, 0.4988, 0.5141), (0.2281, 0.2557, 0.2630))
        ])
    grayscale_transform=transforms.Compose([
        transforms.Grayscale(),
        transforms.ToTensor(),
        transforms.RandomHorizontalFlip(),     
        transforms.Normalize((0.5067), (0.2424))
        ])
    hand_transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.0217), (0.1261))
        ])
    transform = normal_transform
    train = 'new_train'
    test = 'new_test'
    if check == 1:
        print("ran this")
        transform = grayscale_transform
    if check == 2:
        #run code for handlandmark
        transform = hand_transform
        train = 'hand_train'
        test = 'hand_test'
    if check == 3:
         transform = horizontal_transform
        
        
        
    train_dataset = ImageFolder(train, transform=transform)
    test_dataset = ImageFolder(test, transform=transform)

    train_loader = torch.utils.data.DataLoader(train_dataset, **train_kwargs, shuffle=True)
    test_loader = torch.utils.data.DataLoader(test_dataset, **test_kwargs, shuffle=False)
    return train_loader, test_loader

def main():
    # Define settings in a dictionary
    args = {
        'batch_size': 64,
        'test_batch_size': 1000,
        'epochs': 10,
        'lr': 1.0,
        'gamma': 0.7,
        'no_cuda': False,
        'no_mps': False,
        'dry_run': False,
        'seed': 1,
        'log_interval': 10,
        'save_model': True,
        'transform': 'handlandmark'
    }

    # Use settings from the dictionary
    use_cuda = not args['no_cuda'] and torch.cuda.is_available()
    use_mps = not args['no_mps'] and torch.backends.mps.is_available()

    torch.manual_seed(args['seed'])

    device = torch.device("cuda" if use_cuda else "mps" if use_mps else "cpu")
    
    print(f'Using device: {device}')

    train_kwargs = {'batch_size': args['batch_size']}
    test_kwargs = {'batch_size': args['test_batch_size']}

    if use_cuda:
        cuda_kwargs = {'num_workers': 1, 'pin_memory': True, 'shuffle': True}
        train_kwargs.update(cuda_kwargs)
        test_kwargs.update(cuda_kwargs)
    
    check = 0
    in_channels = 3
    if args['transform'] == "grayscale":
        check = 1
        in_channels = 1
    elif args['transform'] == "handlandmark":
        check = 2
    elif args['transform'] == "horizontal":
        check = 3
        
    train_loader, test_loader = load_data(train_kwargs, test_kwargs, check)

    model = Net(in_channels).to(device)
    optimizer = optim.Adadelta(model.parameters(), lr=args['lr'])

    scheduler = StepLR(optimizer, step_size=1, gamma=args['gamma'])
    
    for epoch in range(1, args['epochs'] + 1):
        train(args, model, device, train_loader, optimizer, epoch)
        test(model, device, test_loader)
        scheduler.step()

        all_targets, all_preds = evaluate_model(model, device, test_loader)
        class_to_idx = {v: k for k, v in train_loader.dataset.class_to_idx.items()}
        plot_confusion_matrix(all_targets, all_preds, class_to_idx)

    final_evaluation(model, device, test_loader)

    if args['save_model']:
        torch.save(model.state_dict(), "mnist_cnn.pt")

if __name__ == '__main__':
    main()
# Out:
# Using device: mps
# Train Epoch: 1 [0/6695 (0%)]	Loss: 3.373475	Accuracy: 4.69%
# Train Epoch: 1 [640/6695 (10%)]	Loss: 3.355505	Accuracy: 4.26%
# Train Epoch: 1 [1280/6695 (19%)]	Loss: 3.378717	Accuracy: 4.99%
# Train Epoch: 1 [1920/6695 (29%)]	Loss: 3.334777	Accuracy: 6.75%
# Train Epoch: 1 [2560/6695 (38%)]	Loss: 3.287662	Accuracy: 7.89%
# Train Epoch: 1 [3200/6695 (48%)]	Loss: 3.140181	Accuracy: 9.19%
# Train Epoch: 1 [3840/6695 (57%)]	Loss: 3.151750	Accuracy: 9.99%
# Train Epoch: 1 [4480/6695 (67%)]	Loss: 3.938739	Accuracy: 10.34%
# Train Epoch: 1 [5120/6695 (76%)]	Loss: 3.117066	Accuracy: 10.78%
# Train Epoch: 1 [5760/6695 (86%)]	Loss: 2.529366	Accuracy: 11.61%
# Train Epoch: 1 [6400/6695 (95%)]	Loss: 2.709068	Accuracy: 12.70%
# Epoch: 1 Training Accuracy: 13.08%
#
# Test set: Average loss: 2.7555, Accuracy: 548/2924 (19%)
# Most frequently missed letter: P (Index: 17) with 110 misses
# Train Epoch: 2 [0/6695 (0%)]	Loss: 2.418681	Accuracy: 28.12%
# Train Epoch: 2 [640/6695 (10%)]	Loss: 2.243745	Accuracy: 32.24%
# Train Epoch: 2 [1280/6695 (19%)]	Loss: 2.037747	Accuracy: 33.26%
# Train Epoch: 2 [1920/6695 (29%)]	Loss: 1.950875	Accuracy: 34.38%
# Train Epoch: 2 [2560/6695 (38%)]	Loss: 1.927121	Accuracy: 36.13%
# Train Epoch: 2 [3200/6695 (48%)]	Loss: 1.682674	Accuracy: 37.19%
# Train Epoch: 2 [3840/6695 (57%)]	Loss: 1.655103	Accuracy: 37.99%
# Train Epoch: 2 [4480/6695 (67%)]	Loss: 1.811605	Accuracy: 39.02%
# Train Epoch: 2 [5120/6695 (76%)]	Loss: 1.766154	Accuracy: 40.01%
# Train Epoch: 2 [5760/6695 (86%)]	Loss: 1.634846	Accuracy: 40.88%
# Train Epoch: 2 [6400/6695 (95%)]	Loss: 1.545593	Accuracy: 41.52%
# Epoch: 2 Training Accuracy: 41.87%
#
# Test set: Average loss: 3.4480, Accuracy: 1175/2924 (40%)
# Most frequently missed letter: Nothing (Index: 4) with 96 misses
# Train Epoch: 3 [0/6695 (0%)]	Loss: 1.444889	Accuracy: 60.94%
# Train Epoch: 3 [640/6695 (10%)]	Loss: 1.342920	Accuracy: 59.94%
# Train Epoch: 3 [1280/6695 (19%)]	Loss: 1.005113	Accuracy: 63.62%
# Train Epoch: 3 [1920/6695 (29%)]	Loss: 1.236560	Accuracy: 64.42%
# Train Epoch: 3 [2560/6695 (38%)]	Loss: 0.945785	Accuracy: 65.28%
# Train Epoch: 3 [3200/6695 (48%)]	Loss: 0.903491	Accuracy: 65.62%
# Train Epoch: 3 [3840/6695 (57%)]	Loss: 0.855739	Accuracy: 66.03%
# Train Epoch: 3 [4480/6695 (67%)]	Loss: 1.086885	Accuracy: 66.53%
# Train Epoch: 3 [5120/6695 (76%)]	Loss: 0.947212	Accuracy: 66.47%
# Train Epoch: 3 [5760/6695 (86%)]	Loss: 0.901741	Accuracy: 66.69%
# Train Epoch: 3 [6400/6695 (95%)]	Loss: 0.975046	Accuracy: 66.46%
# Epoch: 3 Training Accuracy: 66.53%
#
# Test set: Average loss: 3.4007, Accuracy: 1580/2924 (54%)
# Most frequently missed letter: Delete (Index: 13) with 82 misses
# Train Epoch: 4 [0/6695 (0%)]	Loss: 0.781781	Accuracy: 70.31%
# Train Epoch: 4 [640/6695 (10%)]	Loss: 0.441187	Accuracy: 81.68%
# Train Epoch: 4 [1280/6695 (19%)]	Loss: 0.710517	Accuracy: 80.28%
# Train Epoch: 4 [1920/6695 (29%)]	Loss: 0.525828	Accuracy: 81.10%
# Train Epoch: 4 [2560/6695 (38%)]	Loss: 0.879637	Accuracy: 80.95%
# Train Epoch: 4 [3200/6695 (48%)]	Loss: 0.382363	Accuracy: 81.00%
# Train Epoch: 4 [3840/6695 (57%)]	Loss: 0.649214	Accuracy: 80.71%
# Train Epoch: 4 [4480/6695 (67%)]	Loss: 0.596198	Accuracy: 81.01%
# Train Epoch: 4 [5120/6695 (76%)]	Loss: 0.470695	Accuracy: 81.06%
# Train Epoch: 4 [5760/6695 (86%)]	Loss: 0.624220	Accuracy: 80.79%
# Train Epoch: 4 [6400/6695 (95%)]	Loss: 0.482882	Accuracy: 80.77%
# Epoch: 4 Training Accuracy: 80.88%
#
# Test set: Average loss: 4.2786, Accuracy: 1676/2924 (57%)
# Most frequently missed letter: Delete (Index: 13) with 77 misses
# Train Epoch: 5 [0/6695 (0%)]	Loss: 0.219377	Accuracy: 93.75%
# Train Epoch: 5 [640/6695 (10%)]	Loss: 0.379522	Accuracy: 88.21%
# Train Epoch: 5 [1280/6695 (19%)]	Loss: 0.426290	Accuracy: 88.02%
# Train Epoch: 5 [1920/6695 (29%)]	Loss: 0.383262	Accuracy: 88.56%
# Train Epoch: 5 [2560/6695 (38%)]	Loss: 0.196021	Accuracy: 89.06%
# Train Epoch: 5 [3200/6695 (48%)]	Loss: 0.296092	Accuracy: 88.60%
# Train Epoch: 5 [3840/6695 (57%)]	Loss: 0.425441	Accuracy: 88.32%
# Train Epoch: 5 [4480/6695 (67%)]	Loss: 0.395303	Accuracy: 88.14%
# Train Epoch: 5 [5120/6695 (76%)]	Loss: 0.341458	Accuracy: 88.25%
# Train Epoch: 5 [5760/6695 (86%)]	Loss: 0.288164	Accuracy: 88.17%
# Train Epoch: 5 [6400/6695 (95%)]	Loss: 0.414124	Accuracy: 88.34%
# Epoch: 5 Training Accuracy: 88.45%
#
# Test set: Average loss: 5.2403, Accuracy: 1760/2924 (60%)
# Most frequently missed letter: Delete (Index: 13) with 75 misses
# Train Epoch: 6 [0/6695 (0%)]	Loss: 0.225535	Accuracy: 93.75%
# Train Epoch: 6 [640/6695 (10%)]	Loss: 0.257566	Accuracy: 93.04%
# Train Epoch: 6 [1280/6695 (19%)]	Loss: 0.160088	Accuracy: 92.56%
# Train Epoch: 6 [1920/6695 (29%)]	Loss: 0.165687	Accuracy: 92.54%
# Train Epoch: 6 [2560/6695 (38%)]	Loss: 0.309374	Accuracy: 92.61%
# Train Epoch: 6 [3200/6695 (48%)]	Loss: 0.227068	Accuracy: 92.43%
# Train Epoch: 6 [3840/6695 (57%)]	Loss: 0.283798	Accuracy: 92.65%
# Train Epoch: 6 [4480/6695 (67%)]	Loss: 0.254440	Accuracy: 92.67%
# Train Epoch: 6 [5120/6695 (76%)]	Loss: 0.394474	Accuracy: 92.65%
# Train Epoch: 6 [5760/6695 (86%)]	Loss: 0.103470	Accuracy: 92.67%
# Train Epoch: 6 [6400/6695 (95%)]	Loss: 0.308517	Accuracy: 92.62%
# Epoch: 6 Training Accuracy: 92.68%
#
# Test set: Average loss: 5.9502, Accuracy: 1771/2924 (61%)
# Most frequently missed letter: Delete (Index: 13) with 78 misses
# Train Epoch: 7 [0/6695 (0%)]	Loss: 0.159365	Accuracy: 93.75%
# Train Epoch: 7 [640/6695 (10%)]	Loss: 0.183599	Accuracy: 93.75%
# Train Epoch: 7 [1280/6695 (19%)]	Loss: 0.324770	Accuracy: 93.15%
# Train Epoch: 7 [1920/6695 (29%)]	Loss: 0.251255	Accuracy: 93.30%
# Train Epoch: 7 [2560/6695 (38%)]	Loss: 0.105364	Accuracy: 93.48%
# Train Epoch: 7 [3200/6695 (48%)]	Loss: 0.157292	Accuracy: 93.75%
# Train Epoch: 7 [3840/6695 (57%)]	Loss: 0.126205	Accuracy: 94.06%
# Train Epoch: 7 [4480/6695 (67%)]	Loss: 0.082505	Accuracy: 94.19%
# Train Epoch: 7 [5120/6695 (76%)]	Loss: 0.325240	Accuracy: 94.12%
# Train Epoch: 7 [5760/6695 (86%)]	Loss: 0.156622	Accuracy: 94.01%
# Train Epoch: 7 [6400/6695 (95%)]	Loss: 0.209708	Accuracy: 94.12%
# Epoch: 7 Training Accuracy: 94.16%
#
# Test set: Average loss: 6.1470, Accuracy: 1804/2924 (62%)
# Most frequently missed letter: Delete (Index: 13) with 76 misses
# Train Epoch: 8 [0/6695 (0%)]	Loss: 0.074890	Accuracy: 98.44%
# Train Epoch: 8 [640/6695 (10%)]	Loss: 0.105447	Accuracy: 94.74%
# Train Epoch: 8 [1280/6695 (19%)]	Loss: 0.062934	Accuracy: 95.46%
# Train Epoch: 8 [1920/6695 (29%)]	Loss: 0.099979	Accuracy: 95.61%
# Train Epoch: 8 [2560/6695 (38%)]	Loss: 0.141375	Accuracy: 95.88%
# Train Epoch: 8 [3200/6695 (48%)]	Loss: 0.051473	Accuracy: 96.08%
# Train Epoch: 8 [3840/6695 (57%)]	Loss: 0.267895	Accuracy: 95.80%
# Train Epoch: 8 [4480/6695 (67%)]	Loss: 0.137749	Accuracy: 95.84%
# Train Epoch: 8 [5120/6695 (76%)]	Loss: 0.150285	Accuracy: 95.87%
# Train Epoch: 8 [5760/6695 (86%)]	Loss: 0.075050	Accuracy: 95.90%
# Train Epoch: 8 [6400/6695 (95%)]	Loss: 0.078316	Accuracy: 96.01%
# Epoch: 8 Training Accuracy: 96.06%
#
# Test set: Average loss: 6.6232, Accuracy: 1819/2924 (62%)
# Most frequently missed letter: Delete (Index: 13) with 76 misses
# Train Epoch: 9 [0/6695 (0%)]	Loss: 0.099994	Accuracy: 95.31%
# Train Epoch: 9 [640/6695 (10%)]	Loss: 0.168403	Accuracy: 96.31%
# Train Epoch: 9 [1280/6695 (19%)]	Loss: 0.050465	Accuracy: 96.28%
# Train Epoch: 9 [1920/6695 (29%)]	Loss: 0.121692	Accuracy: 96.98%
# Train Epoch: 9 [2560/6695 (38%)]	Loss: 0.118334	Accuracy: 96.95%
# Train Epoch: 9 [3200/6695 (48%)]	Loss: 0.089351	Accuracy: 96.54%
# Train Epoch: 9 [3840/6695 (57%)]	Loss: 0.044820	Accuracy: 96.44%
# Train Epoch: 9 [4480/6695 (67%)]	Loss: 0.064747	Accuracy: 96.57%
# Train Epoch: 9 [5120/6695 (76%)]	Loss: 0.142598	Accuracy: 96.60%
# Train Epoch: 9 [5760/6695 (86%)]	Loss: 0.053408	Accuracy: 96.60%
# Train Epoch: 9 [6400/6695 (95%)]	Loss: 0.266481	Accuracy: 96.55%
# Epoch: 9 Training Accuracy: 96.56%
#
# Test set: Average loss: 7.0901, Accuracy: 1821/2924 (62%)
# Most frequently missed letter: Delete (Index: 13) with 76 misses
# Train Epoch: 10 [0/6695 (0%)]	Loss: 0.200545	Accuracy: 92.19%
# Train Epoch: 10 [640/6695 (10%)]	Loss: 0.190078	Accuracy: 96.31%
# Train Epoch: 10 [1280/6695 (19%)]	Loss: 0.099277	Accuracy: 97.02%
# Train Epoch: 10 [1920/6695 (29%)]	Loss: 0.073192	Accuracy: 96.93%
# Train Epoch: 10 [2560/6695 (38%)]	Loss: 0.080115	Accuracy: 96.95%
# Train Epoch: 10 [3200/6695 (48%)]	Loss: 0.100106	Accuracy: 97.06%
# Train Epoch: 10 [3840/6695 (57%)]	Loss: 0.168314	Accuracy: 97.05%
# Train Epoch: 10 [4480/6695 (67%)]	Loss: 0.095871	Accuracy: 97.01%
# Train Epoch: 10 [5120/6695 (76%)]	Loss: 0.039747	Accuracy: 97.01%
# Train Epoch: 10 [5760/6695 (86%)]	Loss: 0.104378	Accuracy: 97.17%
# Train Epoch: 10 [6400/6695 (95%)]	Loss: 0.145599	Accuracy: 97.17%
# Epoch: 10 Training Accuracy: 97.10%
#
# Test set: Average loss: 7.2178, Accuracy: 1830/2924 (63%)
# Most frequently missed letter: Delete (Index: 13) with 75 misses
#
# Final Evaluation: Loss: 7.2178, Accuracy: 62.59%, Precision: 0.7953, Recall: 0.6265, F1 Score: 0.6772
