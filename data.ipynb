# %%
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import StepLR
from torchvision.datasets import ImageFolder
from torchvision.transforms import Resize, Grayscale
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


class Net(nn.Module):
    def __init__(self, in_channels):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, 32, 3, padding=1)  # Increased filters and added padding
        self.conv2 = nn.Conv2d(32, 64, 3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, 3, padding=1)  # Additional conv layer
        self.pool = nn.MaxPool2d(2, 2)
        self.dropout1 = nn.Dropout(0.25)
        self.dropout2 = nn.Dropout(0.5)
        self.fc1 = nn.Linear(80000, 512)  # Adjusted to new flattening size and more neurons
        self.fc2 = nn.Linear(512, 128)
        self.fc3 = nn.Linear(128, 29)  # Additional layer

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        x = F.relu(self.conv3(x))
        x = self.pool(x)
        x = self.dropout1(x)
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = self.dropout2(x)
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        output = F.log_softmax(x, dim=1)
        return output


def train(args, model, device, train_loader, optimizer, epoch):
    model.train()
    correct = 0
    total = 0
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()

        # Calculate accuracy
        pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
        correct += pred.eq(target.view_as(pred)).sum().item()
        total += target.size(0)

        if batch_idx % args['log_interval'] == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}\tAccuracy: {:.2f}%'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item(), 100. * correct / total))
            
            # Optional: break after one pass over the data if dry-run is enabled
            if args['dry_run']:
                break

    # Print overall accuracy at the end of the epoch
    print('Epoch: {} Training Accuracy: {:.2f}%'.format(epoch, 100. * correct / total))



def test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()  # sum up batch loss

            # Output tensor check
            
            pred = output.argmax(dim=1)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
            total += target.size(0)


    test_loss /= len(test_loader.dataset)
    accuracy = 100. * correct / len(test_loader.dataset)
    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset), accuracy))

def evaluate_model(model, device, test_loader):
    model.eval()  # Set the model to evaluation mode
    all_preds = []
    all_targets = []

    with torch.no_grad():  # Turn off gradients for evaluation, saves memory and computations
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)  # Move data to the appropriate device
            output = model(data)  # Get model output
            _, preds = torch.max(output, 1)  # Get the index of the max log-probability, which are our predictions

            all_preds.extend(preds.cpu().numpy())  # Store predictions
            all_targets.extend(target.cpu().numpy())  # Store true labels

    return all_targets, all_preds
    

# Assuming you have a test_loader and a device setup

def plot_confusion_matrix(all_targets, all_preds, class_to_idx):
    conf_matrix = confusion_matrix(all_targets, all_preds)
    plt.figure(figsize=(12, 10))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
                xticklabels=[class_to_idx[i] for i in range(len(class_to_idx))],
                yticklabels=[class_to_idx[i] for i in range(len(class_to_idx))])
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')
    plt.show()
    
    # Analyze the confusion matrix to find most frequently missed letters
    missed_counts = np.sum(conf_matrix, axis=1) - np.diag(conf_matrix)
    most_missed_index = np.argmax(missed_counts)
    most_missed_letter = class_to_idx[most_missed_index]
    print(f'Most frequently missed letter: {most_missed_letter} (Index: {most_missed_index}) with {missed_counts[most_missed_index]} misses')

def final_evaluation(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    all_preds = []
    all_targets = []
    
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()
            all_preds.extend(pred.view_as(target).cpu().numpy())
            all_targets.extend(target.cpu().numpy())

    # Metrics Calculation
    test_loss /= len(test_loader.dataset)
    accuracy = 100. * correct / len(test_loader.dataset)
    precision = precision_score(all_targets, all_preds, average='macro')
    recall = recall_score(all_targets, all_preds, average='macro')
    f1 = f1_score(all_targets, all_preds, average='macro')
    
   
    print(f'\nFinal Evaluation: Loss: {test_loss:.4f}, Accuracy: {accuracy:.2f}%, Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1:.4f}')
    


def load_data(train_kwargs, test_kwargs, check):
    normal_transform=transforms.Compose([
        transforms.Resize((200,200),antialias = True),
        transforms.ToTensor(),
        transforms.RandomHorizontalFlip(),     
        #transforms.Normalize((0.5187, 0.4988, 0.5141), (0.2281, 0.2557, 0.2630))
        ])
    horizontal_transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.RandomHorizontalFlip(),     
        transforms.Normalize((0.5187, 0.4988, 0.5141), (0.2281, 0.2557, 0.2630))
        ])
    grayscale_transform=transforms.Compose([
        transforms.Grayscale(),
        transforms.ToTensor(),
        transforms.RandomHorizontalFlip(),     
        transforms.Normalize((0.5067), (0.2424))
        ])
    hand_transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.RandomHorizontalFlip(),
        transforms.Normalize((0.0217), (0.1261))
        ])
    transform = normal_transform
    train = 'new2_train'
    test = 'Hand_Signs'
    if check == 1:
        print("ran this")
        transform = grayscale_transform
    if check == 2:
        #run code for handlandmark
        transform = hand_transform
        train = 'hand2_train'
        test = 'Hang_Signs'
    if check == 3:
         transform = horizontal_transform
        
        
        
    train_dataset = ImageFolder(train, transform=transform)
    test_dataset = ImageFolder(test, transform=transform)

    train_loader = torch.utils.data.DataLoader(train_dataset, **train_kwargs, shuffle=True)
    test_loader = torch.utils.data.DataLoader(test_dataset, **test_kwargs, shuffle=False)
    return train_loader, test_loader

def main():
    # Define settings in a dictionary
    args = {
        'batch_size': 64,
        'test_batch_size': 1000,
        'epochs': 10,
        'lr': 1.0,
        'gamma': 0.7,
        'no_cuda': False,
        'no_mps': False,
        'dry_run': False,
        'seed': 1,
        'log_interval': 10,
        'save_model': True,
        'transform': 'grayscale'
    }

    # Use settings from the dictionary
    use_cuda = not args['no_cuda'] and torch.cuda.is_available()
    use_mps = not args['no_mps'] and torch.backends.mps.is_available()

    torch.manual_seed(args['seed'])

    device = torch.device("cuda" if use_cuda else "mps" if use_mps else "cpu")
    
    print(f'Using device: {device}')

    train_kwargs = {'batch_size': args['batch_size']}
    test_kwargs = {'batch_size': args['test_batch_size']}

    if use_cuda:
        cuda_kwargs = {'num_workers': 1, 'pin_memory': True, 'shuffle': True}
        train_kwargs.update(cuda_kwargs)
        test_kwargs.update(cuda_kwargs)
    
    check = 0
    in_channels = 3
    if args['transform'] == "grayscale":
        check = 1
        in_channels = 1
    elif args['transform'] == "handlandmark":
        check = 2
    elif args['transform'] == "horizontal":
        check = 3
        
    train_loader, test_loader = load_data(train_kwargs, test_kwargs, check)

    model = Net(in_channels).to(device)
    optimizer = optim.Adadelta(model.parameters(), lr=args['lr'])

    scheduler = StepLR(optimizer, step_size=1, gamma=args['gamma'])
    
    for epoch in range(1, args['epochs'] + 1):
        train(args, model, device, train_loader, optimizer, epoch)
        test(model, device, test_loader)
        scheduler.step()

        all_targets, all_preds = evaluate_model(model, device, test_loader)
        class_to_idx = {v: k for k, v in train_loader.dataset.class_to_idx.items()}
        plot_confusion_matrix(all_targets, all_preds, class_to_idx)

    final_evaluation(model, device, test_loader)

    if args['save_model']:
        torch.save(model.state_dict(), "mnist_cnn.pt")

if __name__ == '__main__':
    main()
# Out:
# Using device: mps
# ran this
# Train Epoch: 1 [0/23258 (0%)]	Loss: 3.367588	Accuracy: 6.25%
# Train Epoch: 1 [640/23258 (3%)]	Loss: 3.356046	Accuracy: 2.84%
# Train Epoch: 1 [1280/23258 (5%)]	Loss: 3.367585	Accuracy: 2.98%
# Train Epoch: 1 [1920/23258 (8%)]	Loss: 3.364474	Accuracy: 3.33%
# Train Epoch: 1 [2560/23258 (11%)]	Loss: 3.351587	Accuracy: 3.77%
# Train Epoch: 1 [3200/23258 (14%)]	Loss: 3.338525	Accuracy: 4.47%
# Train Epoch: 1 [3840/23258 (16%)]	Loss: 3.266926	Accuracy: 4.92%
# Train Epoch: 1 [4480/23258 (19%)]	Loss: 3.011382	Accuracy: 5.04%
# Train Epoch: 1 [5120/23258 (22%)]	Loss: 3.165662	Accuracy: 5.52%
# Train Epoch: 1 [5760/23258 (25%)]	Loss: 3.018020	Accuracy: 6.03%
# Train Epoch: 1 [6400/23258 (27%)]	Loss: 3.035975	Accuracy: 6.37%
# Train Epoch: 1 [7040/23258 (30%)]	Loss: 3.090577	Accuracy: 6.80%
# Train Epoch: 1 [7680/23258 (33%)]	Loss: 2.940711	Accuracy: 7.43%
# Train Epoch: 1 [8320/23258 (36%)]	Loss: 3.115614	Accuracy: 7.78%
# Train Epoch: 1 [8960/23258 (38%)]	Loss: 2.746827	Accuracy: 8.36%
# Train Epoch: 1 [9600/23258 (41%)]	Loss: 2.715923	Accuracy: 8.71%
# Train Epoch: 1 [10240/23258 (44%)]	Loss: 2.682941	Accuracy: 9.33%
# Train Epoch: 1 [10880/23258 (47%)]	Loss: 2.598939	Accuracy: 9.69%
# Train Epoch: 1 [11520/23258 (49%)]	Loss: 2.408998	Accuracy: 10.14%
# Train Epoch: 1 [12160/23258 (52%)]	Loss: 2.467083	Accuracy: 10.59%
# Train Epoch: 1 [12800/23258 (55%)]	Loss: 2.465882	Accuracy: 11.07%
# Train Epoch: 1 [13440/23258 (58%)]	Loss: 2.444244	Accuracy: 11.55%
# Train Epoch: 1 [14080/23258 (60%)]	Loss: 2.320601	Accuracy: 11.97%
# Train Epoch: 1 [14720/23258 (63%)]	Loss: 2.175778	Accuracy: 12.45%
# Train Epoch: 1 [15360/23258 (66%)]	Loss: 2.255605	Accuracy: 12.91%
# Train Epoch: 1 [16000/23258 (69%)]	Loss: 2.119790	Accuracy: 13.49%
# Train Epoch: 1 [16640/23258 (71%)]	Loss: 2.303605	Accuracy: 13.86%
# Train Epoch: 1 [17280/23258 (74%)]	Loss: 2.067628	Accuracy: 14.35%
# Train Epoch: 1 [17920/23258 (77%)]	Loss: 1.934018	Accuracy: 14.82%
# Train Epoch: 1 [18560/23258 (80%)]	Loss: 1.919827	Accuracy: 15.28%
# Train Epoch: 1 [19200/23258 (82%)]	Loss: 2.056730	Accuracy: 15.78%
# Train Epoch: 1 [19840/23258 (85%)]	Loss: 2.356041	Accuracy: 16.17%
# Train Epoch: 1 [20480/23258 (88%)]	Loss: 1.828534	Accuracy: 16.68%
# Train Epoch: 1 [21120/23258 (91%)]	Loss: 2.146233	Accuracy: 17.15%
# Train Epoch: 1 [21760/23258 (93%)]	Loss: 1.998120	Accuracy: 17.67%
# Train Epoch: 1 [22400/23258 (96%)]	Loss: 1.877274	Accuracy: 18.14%
# Train Epoch: 1 [23040/23258 (99%)]	Loss: 1.813083	Accuracy: 18.65%
# Epoch: 1 Training Accuracy: 18.76%
#
# Test set: Average loss: 5.1594, Accuracy: 2/135 (1%)
# Most frequently missed letter: A (Index: 0) with 5 misses
# Train Epoch: 2 [0/23258 (0%)]	Loss: 1.855135	Accuracy: 32.81%
# Train Epoch: 2 [640/23258 (3%)]	Loss: 1.631955	Accuracy: 42.19%
# Train Epoch: 2 [1280/23258 (5%)]	Loss: 1.650369	Accuracy: 41.67%
# Train Epoch: 2 [1920/23258 (8%)]	Loss: 1.606928	Accuracy: 41.78%
# Train Epoch: 2 [2560/23258 (11%)]	Loss: 1.478022	Accuracy: 42.57%
# Train Epoch: 2 [3200/23258 (14%)]	Loss: 1.636397	Accuracy: 42.92%
# Train Epoch: 2 [3840/23258 (16%)]	Loss: 1.361881	Accuracy: 43.93%
# Train Epoch: 2 [4480/23258 (19%)]	Loss: 1.625900	Accuracy: 44.41%
# Train Epoch: 2 [5120/23258 (22%)]	Loss: 1.324926	Accuracy: 44.97%
# Train Epoch: 2 [5760/23258 (25%)]	Loss: 1.359288	Accuracy: 45.38%
# Train Epoch: 2 [6400/23258 (27%)]	Loss: 1.038904	Accuracy: 45.64%
# Train Epoch: 2 [7040/23258 (30%)]	Loss: 1.702988	Accuracy: 46.06%
# Train Epoch: 2 [7680/23258 (33%)]	Loss: 1.208941	Accuracy: 46.54%
# Train Epoch: 2 [8320/23258 (36%)]	Loss: 1.410882	Accuracy: 46.91%
# Train Epoch: 2 [8960/23258 (38%)]	Loss: 1.327654	Accuracy: 47.02%
# Train Epoch: 2 [9600/23258 (41%)]	Loss: 1.190556	Accuracy: 47.61%
# Train Epoch: 2 [10240/23258 (44%)]	Loss: 1.136938	Accuracy: 47.91%
# Train Epoch: 2 [10880/23258 (47%)]	Loss: 1.115308	Accuracy: 48.41%
# Train Epoch: 2 [11520/23258 (49%)]	Loss: 1.280369	Accuracy: 48.60%
# Train Epoch: 2 [12160/23258 (52%)]	Loss: 1.442143	Accuracy: 49.07%
# Train Epoch: 2 [12800/23258 (55%)]	Loss: 0.975510	Accuracy: 49.49%
# Train Epoch: 2 [13440/23258 (58%)]	Loss: 0.885199	Accuracy: 49.93%
# Train Epoch: 2 [14080/23258 (60%)]	Loss: 1.124277	Accuracy: 50.30%
# Train Epoch: 2 [14720/23258 (63%)]	Loss: 0.951922	Accuracy: 50.63%
# Train Epoch: 2 [15360/23258 (66%)]	Loss: 1.138907	Accuracy: 50.95%
# Train Epoch: 2 [16000/23258 (69%)]	Loss: 1.059222	Accuracy: 51.39%
# Train Epoch: 2 [16640/23258 (71%)]	Loss: 1.203823	Accuracy: 51.62%
# Train Epoch: 2 [17280/23258 (74%)]	Loss: 1.168725	Accuracy: 51.99%
# Train Epoch: 2 [17920/23258 (77%)]	Loss: 0.950257	Accuracy: 52.25%
# Train Epoch: 2 [18560/23258 (80%)]	Loss: 0.861787	Accuracy: 52.62%
# Train Epoch: 2 [19200/23258 (82%)]	Loss: 0.865499	Accuracy: 52.87%
# Train Epoch: 2 [19840/23258 (85%)]	Loss: 0.924713	Accuracy: 53.24%
# Train Epoch: 2 [20480/23258 (88%)]	Loss: 1.120238	Accuracy: 53.48%
# Train Epoch: 2 [21120/23258 (91%)]	Loss: 0.961192	Accuracy: 53.72%
# Train Epoch: 2 [21760/23258 (93%)]	Loss: 1.165494	Accuracy: 54.00%
# Train Epoch: 2 [22400/23258 (96%)]	Loss: 0.952335	Accuracy: 54.27%
# Train Epoch: 2 [23040/23258 (99%)]	Loss: 0.899721	Accuracy: 54.59%
# Epoch: 2 Training Accuracy: 54.64%
#
# Test set: Average loss: 6.1056, Accuracy: 6/135 (4%)
# Most frequently missed letter: A (Index: 0) with 5 misses
# Train Epoch: 3 [0/23258 (0%)]	Loss: 1.216659	Accuracy: 57.81%
# Train Epoch: 3 [640/23258 (3%)]	Loss: 0.933088	Accuracy: 65.91%
# Train Epoch: 3 [1280/23258 (5%)]	Loss: 0.679128	Accuracy: 69.27%
# Train Epoch: 3 [1920/23258 (8%)]	Loss: 1.261172	Accuracy: 69.15%
# Train Epoch: 3 [2560/23258 (11%)]	Loss: 0.781454	Accuracy: 70.16%
# Train Epoch: 3 [3200/23258 (14%)]	Loss: 0.781729	Accuracy: 70.71%
# Train Epoch: 3 [3840/23258 (16%)]	Loss: 0.666720	Accuracy: 70.18%
# Train Epoch: 3 [4480/23258 (19%)]	Loss: 0.670627	Accuracy: 70.44%
# Train Epoch: 3 [5120/23258 (22%)]	Loss: 0.971381	Accuracy: 70.16%
# Train Epoch: 3 [5760/23258 (25%)]	Loss: 0.799293	Accuracy: 70.11%
# Train Epoch: 3 [6400/23258 (27%)]	Loss: 0.828123	Accuracy: 70.08%
# Train Epoch: 3 [7040/23258 (30%)]	Loss: 0.612180	Accuracy: 70.45%
# Train Epoch: 3 [7680/23258 (33%)]	Loss: 0.721311	Accuracy: 70.64%
# Train Epoch: 3 [8320/23258 (36%)]	Loss: 0.719162	Accuracy: 70.54%
# Train Epoch: 3 [8960/23258 (38%)]	Loss: 1.191997	Accuracy: 70.48%
# Train Epoch: 3 [9600/23258 (41%)]	Loss: 0.565937	Accuracy: 70.55%
# Train Epoch: 3 [10240/23258 (44%)]	Loss: 0.783359	Accuracy: 70.71%
# Train Epoch: 3 [10880/23258 (47%)]	Loss: 0.620602	Accuracy: 70.89%
# Train Epoch: 3 [11520/23258 (49%)]	Loss: 0.643069	Accuracy: 71.00%
# Train Epoch: 3 [12160/23258 (52%)]	Loss: 0.605636	Accuracy: 71.20%
# Train Epoch: 3 [12800/23258 (55%)]	Loss: 0.621486	Accuracy: 71.22%
# Train Epoch: 3 [13440/23258 (58%)]	Loss: 0.935924	Accuracy: 71.43%
# Train Epoch: 3 [14080/23258 (60%)]	Loss: 0.492942	Accuracy: 71.40%
# Train Epoch: 3 [14720/23258 (63%)]	Loss: 0.711937	Accuracy: 71.62%
# Train Epoch: 3 [15360/23258 (66%)]	Loss: 0.507665	Accuracy: 71.82%
# Train Epoch: 3 [16000/23258 (69%)]	Loss: 0.633239	Accuracy: 72.01%
# Train Epoch: 3 [16640/23258 (71%)]	Loss: 0.663669	Accuracy: 72.15%
# Train Epoch: 3 [17280/23258 (74%)]	Loss: 0.518324	Accuracy: 72.32%
# Train Epoch: 3 [17920/23258 (77%)]	Loss: 0.667542	Accuracy: 72.36%
# Train Epoch: 3 [18560/23258 (80%)]	Loss: 0.740631	Accuracy: 72.48%
# Train Epoch: 3 [19200/23258 (82%)]	Loss: 0.830837	Accuracy: 72.58%
# Train Epoch: 3 [19840/23258 (85%)]	Loss: 0.548564	Accuracy: 72.71%
# Train Epoch: 3 [20480/23258 (88%)]	Loss: 0.615393	Accuracy: 72.81%
# Train Epoch: 3 [21120/23258 (91%)]	Loss: 0.741425	Accuracy: 72.96%
# Train Epoch: 3 [21760/23258 (93%)]	Loss: 0.801822	Accuracy: 73.02%
# Train Epoch: 3 [22400/23258 (96%)]	Loss: 0.431762	Accuracy: 73.11%
# Train Epoch: 3 [23040/23258 (99%)]	Loss: 0.551129	Accuracy: 73.26%
# Epoch: 3 Training Accuracy: 73.31%
#
# Test set: Average loss: 7.3757, Accuracy: 5/135 (4%)
# Most frequently missed letter: A (Index: 0) with 5 misses
# Train Epoch: 4 [0/23258 (0%)]	Loss: 0.546954	Accuracy: 82.81%
# Train Epoch: 4 [640/23258 (3%)]	Loss: 0.592922	Accuracy: 78.12%
# Train Epoch: 4 [1280/23258 (5%)]	Loss: 0.453128	Accuracy: 78.35%
# Train Epoch: 4 [1920/23258 (8%)]	Loss: 0.567082	Accuracy: 78.63%
# Train Epoch: 4 [2560/23258 (11%)]	Loss: 0.457438	Accuracy: 79.92%
# Train Epoch: 4 [3200/23258 (14%)]	Loss: 0.448496	Accuracy: 79.78%
# Train Epoch: 4 [3840/23258 (16%)]	Loss: 0.507705	Accuracy: 80.12%
# Train Epoch: 4 [4480/23258 (19%)]	Loss: 0.231412	Accuracy: 80.33%
# Train Epoch: 4 [5120/23258 (22%)]	Loss: 0.354446	Accuracy: 80.57%
# Train Epoch: 4 [5760/23258 (25%)]	Loss: 0.703498	Accuracy: 80.60%
# Train Epoch: 4 [6400/23258 (27%)]	Loss: 0.495805	Accuracy: 80.77%
# Train Epoch: 4 [7040/23258 (30%)]	Loss: 0.641156	Accuracy: 81.00%
# Train Epoch: 4 [7680/23258 (33%)]	Loss: 0.617347	Accuracy: 80.95%
# Train Epoch: 4 [8320/23258 (36%)]	Loss: 0.702247	Accuracy: 80.93%
# Train Epoch: 4 [8960/23258 (38%)]	Loss: 0.454644	Accuracy: 80.97%
# Train Epoch: 4 [9600/23258 (41%)]	Loss: 0.614255	Accuracy: 81.24%
# Train Epoch: 4 [10240/23258 (44%)]	Loss: 0.359429	Accuracy: 81.30%
