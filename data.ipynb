# %%
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import StepLR
from torchvision.datasets import ImageFolder
from torchvision.transforms import Resize, Grayscale
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


class Net(nn.Module):
    def __init__(self, in_channels):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, 32, 3, padding=1)  # Increased filters and added padding
        self.conv2 = nn.Conv2d(32, 64, 3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, 3, padding=1)  # Additional conv layer
        self.pool = nn.MaxPool2d(2, 2)
        self.dropout1 = nn.Dropout(0.25)
        self.dropout2 = nn.Dropout(0.5)
        self.fc1 = nn.Linear(80000, 512)  # Adjusted to new flattening size and more neurons
        self.fc2 = nn.Linear(512, 128)
        self.fc3 = nn.Linear(128, 29)  # Additional layer

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        x = F.relu(self.conv3(x))
        x = self.pool(x)
        x = self.dropout1(x)
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = self.dropout2(x)
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        output = F.log_softmax(x, dim=1)
        return output


def train(args, model, device, train_loader, optimizer, epoch):
    model.train()
    correct = 0
    total = 0
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()

        # Calculate accuracy
        pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
        correct += pred.eq(target.view_as(pred)).sum().item()
        total += target.size(0)

        if batch_idx % args['log_interval'] == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}\tAccuracy: {:.2f}%'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item(), 100. * correct / total))
            
            # Optional: break after one pass over the data if dry-run is enabled
            if args['dry_run']:
                break

    # Print overall accuracy at the end of the epoch
    print('Epoch: {} Training Accuracy: {:.2f}%'.format(epoch, 100. * correct / total))



def test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()  # sum up batch loss

            # Output tensor check
            
            pred = output.argmax(dim=1)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
            total += target.size(0)


    test_loss /= len(test_loader.dataset)
    accuracy = 100. * correct / len(test_loader.dataset)
    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset), accuracy))

def evaluate_model(model, device, test_loader):
    model.eval()  # Set the model to evaluation mode
    all_preds = []
    all_targets = []

    with torch.no_grad():  # Turn off gradients for evaluation, saves memory and computations
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)  # Move data to the appropriate device
            output = model(data)  # Get model output
            _, preds = torch.max(output, 1)  # Get the index of the max log-probability, which are our predictions

            all_preds.extend(preds.cpu().numpy())  # Store predictions
            all_targets.extend(target.cpu().numpy())  # Store true labels

    return all_targets, all_preds
    

# Assuming you have a test_loader and a device setup

def plot_confusion_matrix(all_targets, all_preds, class_to_idx):
    conf_matrix = confusion_matrix(all_targets, all_preds)
    plt.figure(figsize=(12, 10))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
                xticklabels=[class_to_idx[i] for i in range(len(class_to_idx))],
                yticklabels=[class_to_idx[i] for i in range(len(class_to_idx))])
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')
    plt.show()
    
    # Analyze the confusion matrix to find most frequently missed letters
    missed_counts = np.sum(conf_matrix, axis=1) - np.diag(conf_matrix)
    most_missed_index = np.argmax(missed_counts)
    most_missed_letter = class_to_idx[most_missed_index]
    print(f'Most frequently missed letter: {most_missed_letter} (Index: {most_missed_index}) with {missed_counts[most_missed_index]} misses')

def final_evaluation(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    all_preds = []
    all_targets = []
    
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()
            all_preds.extend(pred.view_as(target).cpu().numpy())
            all_targets.extend(target.cpu().numpy())

    # Metrics Calculation
    test_loss /= len(test_loader.dataset)
    accuracy = 100. * correct / len(test_loader.dataset)
    precision = precision_score(all_targets, all_preds, average='macro')
    recall = recall_score(all_targets, all_preds, average='macro')
    f1 = f1_score(all_targets, all_preds, average='macro')
    
   
    print(f'\nFinal Evaluation: Loss: {test_loss:.4f}, Accuracy: {accuracy:.2f}%, Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1:.4f}')
    


def load_data(train_kwargs, test_kwargs, check):
    normal_transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.RandomHorizontalFlip(),     
        transforms.Normalize((0.5187, 0.4988, 0.5141), (0.2281, 0.2557, 0.2630))
        ])
    horizontal_transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.RandomHorizontalFlip(),     
        transforms.Normalize((0.5187, 0.4988, 0.5141), (0.2281, 0.2557, 0.2630))
        ])
    grayscale_transform=transforms.Compose([
        transforms.Grayscale(),
        transforms.ToTensor(),
        transforms.RandomHorizontalFlip(),     
        transforms.Normalize((0.5067), (0.2424))
        ])
    hand_transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.RandomHorizontalFlip(),
        transforms.Normalize((0.0217), (0.1261))
        ])
    transform = normal_transform
    train = 'new_train'
    test = 'new_test'
    if check == 1:
        print("ran this")
        transform = grayscale_transform
    if check == 2:
        #run code for handlandmark
        transform = hand_transform
        train = 'hand2_train'
        test = 'hand_not_removed_test'
    if check == 3:
         transform = horizontal_transform
        
        
        
    train_dataset = ImageFolder(train, transform=transform)
    test_dataset = ImageFolder(test, transform=transform)

    train_loader = torch.utils.data.DataLoader(train_dataset, **train_kwargs, shuffle=True)
    test_loader = torch.utils.data.DataLoader(test_dataset, **test_kwargs, shuffle=False)
    return train_loader, test_loader

def main():
    # Define settings in a dictionary
    args = {
        'batch_size': 64,
        'test_batch_size': 1000,
        'epochs': 10,
        'lr': 1.0,
        'gamma': 0.7,
        'no_cuda': False,
        'no_mps': False,
        'dry_run': False,
        'seed': 1,
        'log_interval': 10,
        'save_model': True,
        'transform': 'handlandmark'
    }

    # Use settings from the dictionary
    use_cuda = not args['no_cuda'] and torch.cuda.is_available()
    use_mps = not args['no_mps'] and torch.backends.mps.is_available()

    torch.manual_seed(args['seed'])

    device = torch.device("cuda" if use_cuda else "mps" if use_mps else "cpu")
    
    print(f'Using device: {device}')

    train_kwargs = {'batch_size': args['batch_size']}
    test_kwargs = {'batch_size': args['test_batch_size']}

    if use_cuda:
        cuda_kwargs = {'num_workers': 1, 'pin_memory': True, 'shuffle': True}
        train_kwargs.update(cuda_kwargs)
        test_kwargs.update(cuda_kwargs)
    
    check = 0
    in_channels = 3
    if args['transform'] == "grayscale":
        check = 1
        in_channels = 1
    elif args['transform'] == "handlandmark":
        check = 2
    elif args['transform'] == "horizontal":
        check = 3
        
    train_loader, test_loader = load_data(train_kwargs, test_kwargs, check)

    model = Net(in_channels).to(device)
    optimizer = optim.Adadelta(model.parameters(), lr=args['lr'])

    scheduler = StepLR(optimizer, step_size=1, gamma=args['gamma'])
    
    for epoch in range(1, args['epochs'] + 1):
        train(args, model, device, train_loader, optimizer, epoch)
        test(model, device, test_loader)
        scheduler.step()

        all_targets, all_preds = evaluate_model(model, device, test_loader)
        class_to_idx = {v: k for k, v in train_loader.dataset.class_to_idx.items()}
        plot_confusion_matrix(all_targets, all_preds, class_to_idx)

    final_evaluation(model, device, test_loader)

    if args['save_model']:
        torch.save(model.state_dict(), "mnist_cnn.pt")

if __name__ == '__main__':
    main()
# Out:
# Using device: mps
# Train Epoch: 1 [0/12921 (0%)]	Loss: 3.375121	Accuracy: 0.00%
# Train Epoch: 1 [640/12921 (5%)]	Loss: 3.707837	Accuracy: 3.41%
# Train Epoch: 1 [1280/12921 (10%)]	Loss: 3.311907	Accuracy: 3.57%
# Train Epoch: 1 [1920/12921 (15%)]	Loss: 3.350666	Accuracy: 4.69%
# Train Epoch: 1 [2560/12921 (20%)]	Loss: 3.385326	Accuracy: 5.72%
# Train Epoch: 1 [3200/12921 (25%)]	Loss: 3.347742	Accuracy: 6.62%
# Train Epoch: 1 [3840/12921 (30%)]	Loss: 3.255394	Accuracy: 6.86%
# Train Epoch: 1 [4480/12921 (35%)]	Loss: 3.260077	Accuracy: 7.15%
# Train Epoch: 1 [5120/12921 (40%)]	Loss: 2.943726	Accuracy: 7.75%
# Train Epoch: 1 [5760/12921 (45%)]	Loss: 3.072639	Accuracy: 8.17%
# Train Epoch: 1 [6400/12921 (50%)]	Loss: 2.986835	Accuracy: 8.45%
# Train Epoch: 1 [7040/12921 (54%)]	Loss: 3.167210	Accuracy: 9.02%
# Train Epoch: 1 [7680/12921 (59%)]	Loss: 2.846253	Accuracy: 9.61%
# Train Epoch: 1 [8320/12921 (64%)]	Loss: 2.977379	Accuracy: 10.22%
# Train Epoch: 1 [8960/12921 (69%)]	Loss: 2.474177	Accuracy: 10.77%
# Train Epoch: 1 [9600/12921 (74%)]	Loss: 2.858471	Accuracy: 11.37%
# Train Epoch: 1 [10240/12921 (79%)]	Loss: 2.195033	Accuracy: 11.87%
# Train Epoch: 1 [10880/12921 (84%)]	Loss: 2.294924	Accuracy: 12.56%
# Train Epoch: 1 [11520/12921 (89%)]	Loss: 2.222497	Accuracy: 13.24%
# Train Epoch: 1 [12160/12921 (94%)]	Loss: 2.208645	Accuracy: 13.96%
# Train Epoch: 1 [12800/12921 (99%)]	Loss: 2.121400	Accuracy: 14.62%
# Epoch: 1 Training Accuracy: 14.68%
#
# Test set: Average loss: 2.0504, Accuracy: 1500/4444 (34%)
# Most frequently missed letter: J (Index: 9) with 162 misses
# Train Epoch: 2 [0/12921 (0%)]	Loss: 2.308907	Accuracy: 26.56%
# Train Epoch: 2 [640/12921 (5%)]	Loss: 1.831413	Accuracy: 32.95%
# Train Epoch: 2 [1280/12921 (10%)]	Loss: 1.624985	Accuracy: 35.71%
# Train Epoch: 2 [1920/12921 (15%)]	Loss: 1.853204	Accuracy: 36.09%
# Train Epoch: 2 [2560/12921 (20%)]	Loss: 1.970609	Accuracy: 36.17%
# Train Epoch: 2 [3200/12921 (25%)]	Loss: 1.671603	Accuracy: 37.47%
# Train Epoch: 2 [3840/12921 (30%)]	Loss: 1.833155	Accuracy: 37.60%
# Train Epoch: 2 [4480/12921 (35%)]	Loss: 2.024392	Accuracy: 38.42%
# Train Epoch: 2 [5120/12921 (40%)]	Loss: 1.633618	Accuracy: 38.79%
# Train Epoch: 2 [5760/12921 (45%)]	Loss: 1.748267	Accuracy: 39.58%
# Train Epoch: 2 [6400/12921 (50%)]	Loss: 1.740567	Accuracy: 39.79%
# Train Epoch: 2 [7040/12921 (54%)]	Loss: 1.478020	Accuracy: 40.12%
# Train Epoch: 2 [7680/12921 (59%)]	Loss: 1.823242	Accuracy: 40.29%
# Train Epoch: 2 [8320/12921 (64%)]	Loss: 1.809088	Accuracy: 40.73%
# Train Epoch: 2 [8960/12921 (69%)]	Loss: 1.756445	Accuracy: 41.22%
# Train Epoch: 2 [9600/12921 (74%)]	Loss: 1.532699	Accuracy: 41.85%
# Train Epoch: 2 [10240/12921 (79%)]	Loss: 1.718375	Accuracy: 42.43%
# Train Epoch: 2 [10880/12921 (84%)]	Loss: 1.474590	Accuracy: 43.00%
# Train Epoch: 2 [11520/12921 (89%)]	Loss: 1.534485	Accuracy: 43.25%
# Train Epoch: 2 [12160/12921 (94%)]	Loss: 1.468813	Accuracy: 43.50%
# Train Epoch: 2 [12800/12921 (99%)]	Loss: 1.437501	Accuracy: 43.85%
# Epoch: 2 Training Accuracy: 43.87%
#
# Test set: Average loss: 1.2873, Accuracy: 2657/4444 (60%)
# Most frequently missed letter: S (Index: 18) with 149 misses
# Train Epoch: 3 [0/12921 (0%)]	Loss: 1.564184	Accuracy: 48.44%
# Train Epoch: 3 [640/12921 (5%)]	Loss: 1.201671	Accuracy: 61.65%
# Train Epoch: 3 [1280/12921 (10%)]	Loss: 1.302516	Accuracy: 59.90%
# Train Epoch: 3 [1920/12921 (15%)]	Loss: 1.401648	Accuracy: 60.03%
# Train Epoch: 3 [2560/12921 (20%)]	Loss: 1.591872	Accuracy: 59.57%
# Train Epoch: 3 [3200/12921 (25%)]	Loss: 1.075181	Accuracy: 60.57%
# Train Epoch: 3 [3840/12921 (30%)]	Loss: 1.116342	Accuracy: 60.35%
# Train Epoch: 3 [4480/12921 (35%)]	Loss: 0.990831	Accuracy: 60.98%
# Train Epoch: 3 [5120/12921 (40%)]	Loss: 1.205755	Accuracy: 61.36%
# Train Epoch: 3 [5760/12921 (45%)]	Loss: 1.152995	Accuracy: 61.71%
# Train Epoch: 3 [6400/12921 (50%)]	Loss: 1.163582	Accuracy: 61.90%
# Train Epoch: 3 [7040/12921 (54%)]	Loss: 1.183424	Accuracy: 62.04%
# Train Epoch: 3 [7680/12921 (59%)]	Loss: 0.976242	Accuracy: 62.28%
# Train Epoch: 3 [8320/12921 (64%)]	Loss: 1.120617	Accuracy: 62.51%
# Train Epoch: 3 [8960/12921 (69%)]	Loss: 1.452580	Accuracy: 62.71%
# Train Epoch: 3 [9600/12921 (74%)]	Loss: 1.222795	Accuracy: 62.93%
# Train Epoch: 3 [10240/12921 (79%)]	Loss: 1.054565	Accuracy: 63.15%
# Train Epoch: 3 [10880/12921 (84%)]	Loss: 0.989620	Accuracy: 63.32%
# Train Epoch: 3 [11520/12921 (89%)]	Loss: 0.826559	Accuracy: 63.61%
# Train Epoch: 3 [12160/12921 (94%)]	Loss: 0.703086	Accuracy: 63.87%
# Train Epoch: 3 [12800/12921 (99%)]	Loss: 1.022269	Accuracy: 64.05%
# Epoch: 3 Training Accuracy: 64.07%
#
# Test set: Average loss: 0.7989, Accuracy: 3364/4444 (76%)
# Most frequently missed letter: K (Index: 10) with 83 misses
# Train Epoch: 4 [0/12921 (0%)]	Loss: 0.748724	Accuracy: 75.00%
# Train Epoch: 4 [640/12921 (5%)]	Loss: 0.663380	Accuracy: 73.44%
# Train Epoch: 4 [1280/12921 (10%)]	Loss: 0.543699	Accuracy: 73.66%
# Train Epoch: 4 [1920/12921 (15%)]	Loss: 0.988413	Accuracy: 73.64%
# Train Epoch: 4 [2560/12921 (20%)]	Loss: 1.093859	Accuracy: 73.06%
# Train Epoch: 4 [3200/12921 (25%)]	Loss: 0.585804	Accuracy: 73.62%
# Train Epoch: 4 [3840/12921 (30%)]	Loss: 0.640422	Accuracy: 73.82%
# Train Epoch: 4 [4480/12921 (35%)]	Loss: 0.848078	Accuracy: 74.23%
# Train Epoch: 4 [5120/12921 (40%)]	Loss: 0.714546	Accuracy: 74.25%
# Train Epoch: 4 [5760/12921 (45%)]	Loss: 0.632223	Accuracy: 74.50%
# Train Epoch: 4 [6400/12921 (50%)]	Loss: 0.813947	Accuracy: 74.50%
# Train Epoch: 4 [7040/12921 (54%)]	Loss: 0.636396	Accuracy: 74.56%
# Train Epoch: 4 [7680/12921 (59%)]	Loss: 0.756691	Accuracy: 74.73%
# Train Epoch: 4 [8320/12921 (64%)]	Loss: 0.658271	Accuracy: 74.86%
# Train Epoch: 4 [8960/12921 (69%)]	Loss: 0.784027	Accuracy: 75.09%
# Train Epoch: 4 [9600/12921 (74%)]	Loss: 0.873226	Accuracy: 74.89%
# Train Epoch: 4 [10240/12921 (79%)]	Loss: 0.628624	Accuracy: 75.07%
# Train Epoch: 4 [10880/12921 (84%)]	Loss: 0.576853	Accuracy: 75.17%
# Train Epoch: 4 [11520/12921 (89%)]	Loss: 0.526342	Accuracy: 75.41%
# Train Epoch: 4 [12160/12921 (94%)]	Loss: 0.574659	Accuracy: 75.57%
# Train Epoch: 4 [12800/12921 (99%)]	Loss: 0.648333	Accuracy: 75.58%
# Epoch: 4 Training Accuracy: 75.57%
#
# Test set: Average loss: 0.5962, Accuracy: 3621/4444 (81%)
# Most frequently missed letter: S (Index: 18) with 81 misses
# Train Epoch: 5 [0/12921 (0%)]	Loss: 0.626087	Accuracy: 78.12%
# Train Epoch: 5 [640/12921 (5%)]	Loss: 0.613116	Accuracy: 79.83%
# Train Epoch: 5 [1280/12921 (10%)]	Loss: 0.392200	Accuracy: 81.03%
# Train Epoch: 5 [1920/12921 (15%)]	Loss: 0.689609	Accuracy: 81.25%
# Train Epoch: 5 [2560/12921 (20%)]	Loss: 0.516478	Accuracy: 81.17%
# Train Epoch: 5 [3200/12921 (25%)]	Loss: 0.656411	Accuracy: 81.34%
# Train Epoch: 5 [3840/12921 (30%)]	Loss: 0.339659	Accuracy: 81.74%
# Train Epoch: 5 [4480/12921 (35%)]	Loss: 0.576053	Accuracy: 82.02%
# Train Epoch: 5 [5120/12921 (40%)]	Loss: 0.597370	Accuracy: 81.91%
# Train Epoch: 5 [5760/12921 (45%)]	Loss: 0.670282	Accuracy: 81.99%
# Train Epoch: 5 [6400/12921 (50%)]	Loss: 0.543768	Accuracy: 82.02%
# Train Epoch: 5 [7040/12921 (54%)]	Loss: 0.440166	Accuracy: 82.21%
# Train Epoch: 5 [7680/12921 (59%)]	Loss: 0.493198	Accuracy: 82.31%
# Train Epoch: 5 [8320/12921 (64%)]	Loss: 0.564790	Accuracy: 82.38%
# Train Epoch: 5 [8960/12921 (69%)]	Loss: 0.398119	Accuracy: 82.48%
# Train Epoch: 5 [9600/12921 (74%)]	Loss: 0.543671	Accuracy: 82.41%
# Train Epoch: 5 [10240/12921 (79%)]	Loss: 0.904729	Accuracy: 82.54%
# Train Epoch: 5 [10880/12921 (84%)]	Loss: 0.571941	Accuracy: 82.53%
# Train Epoch: 5 [11520/12921 (89%)]	Loss: 0.581163	Accuracy: 82.42%
# Train Epoch: 5 [12160/12921 (94%)]	Loss: 0.581914	Accuracy: 82.54%
# Train Epoch: 5 [12800/12921 (99%)]	Loss: 0.557412	Accuracy: 82.66%
# Epoch: 5 Training Accuracy: 82.67%
#
# Test set: Average loss: 0.5085, Accuracy: 3773/4444 (85%)
# Most frequently missed letter: U (Index: 20) with 77 misses
# Train Epoch: 6 [0/12921 (0%)]	Loss: 0.444102	Accuracy: 84.38%
# Train Epoch: 6 [640/12921 (5%)]	Loss: 0.303397	Accuracy: 87.07%
# Train Epoch: 6 [1280/12921 (10%)]	Loss: 0.275741	Accuracy: 86.76%
# Train Epoch: 6 [1920/12921 (15%)]	Loss: 0.358359	Accuracy: 85.89%
# Train Epoch: 6 [2560/12921 (20%)]	Loss: 0.496768	Accuracy: 85.98%
# Train Epoch: 6 [3200/12921 (25%)]	Loss: 0.596786	Accuracy: 85.85%
# Train Epoch: 6 [3840/12921 (30%)]	Loss: 0.421996	Accuracy: 86.04%
# Train Epoch: 6 [4480/12921 (35%)]	Loss: 0.452772	Accuracy: 86.11%
# Train Epoch: 6 [5120/12921 (40%)]	Loss: 0.255840	Accuracy: 86.11%
# Train Epoch: 6 [5760/12921 (45%)]	Loss: 0.626522	Accuracy: 86.13%
# Train Epoch: 6 [6400/12921 (50%)]	Loss: 0.371169	Accuracy: 86.25%
# Train Epoch: 6 [7040/12921 (54%)]	Loss: 0.273901	Accuracy: 86.26%
# Train Epoch: 6 [7680/12921 (59%)]	Loss: 0.372667	Accuracy: 86.22%
# Train Epoch: 6 [8320/12921 (64%)]	Loss: 0.351381	Accuracy: 86.15%
# Train Epoch: 6 [8960/12921 (69%)]	Loss: 0.612569	Accuracy: 86.17%
# Train Epoch: 6 [9600/12921 (74%)]	Loss: 0.361124	Accuracy: 86.24%
# Train Epoch: 6 [10240/12921 (79%)]	Loss: 0.416479	Accuracy: 86.32%
# Train Epoch: 6 [10880/12921 (84%)]	Loss: 0.555604	Accuracy: 86.26%
# Train Epoch: 6 [11520/12921 (89%)]	Loss: 0.655396	Accuracy: 86.21%
# Train Epoch: 6 [12160/12921 (94%)]	Loss: 0.336027	Accuracy: 86.08%
# Train Epoch: 6 [12800/12921 (99%)]	Loss: 0.300016	Accuracy: 86.05%
# Epoch: 6 Training Accuracy: 86.06%
#
# Test set: Average loss: 0.4512, Accuracy: 3859/4444 (87%)
# Most frequently missed letter: S (Index: 18) with 71 misses
# Train Epoch: 7 [0/12921 (0%)]	Loss: 0.138891	Accuracy: 98.44%
# Train Epoch: 7 [640/12921 (5%)]	Loss: 0.214110	Accuracy: 90.62%
# Train Epoch: 7 [1280/12921 (10%)]	Loss: 0.426700	Accuracy: 88.99%
# Train Epoch: 7 [1920/12921 (15%)]	Loss: 0.296351	Accuracy: 89.97%
# Train Epoch: 7 [2560/12921 (20%)]	Loss: 0.257844	Accuracy: 89.56%
# Train Epoch: 7 [3200/12921 (25%)]	Loss: 0.487406	Accuracy: 89.58%
# Train Epoch: 7 [3840/12921 (30%)]	Loss: 0.355255	Accuracy: 89.24%
# Train Epoch: 7 [4480/12921 (35%)]	Loss: 0.406620	Accuracy: 89.22%
# Train Epoch: 7 [5120/12921 (40%)]	Loss: 0.160374	Accuracy: 89.08%
# Train Epoch: 7 [5760/12921 (45%)]	Loss: 0.399307	Accuracy: 88.93%
# Train Epoch: 7 [6400/12921 (50%)]	Loss: 0.245108	Accuracy: 88.89%
# Train Epoch: 7 [7040/12921 (54%)]	Loss: 0.401688	Accuracy: 88.91%
# Train Epoch: 7 [7680/12921 (59%)]	Loss: 0.304673	Accuracy: 88.97%
# Train Epoch: 7 [8320/12921 (64%)]	Loss: 0.412898	Accuracy: 89.19%
# Train Epoch: 7 [8960/12921 (69%)]	Loss: 0.303658	Accuracy: 88.98%
# Train Epoch: 7 [9600/12921 (74%)]	Loss: 0.395400	Accuracy: 89.07%
# Train Epoch: 7 [10240/12921 (79%)]	Loss: 0.251689	Accuracy: 89.04%
# Train Epoch: 7 [10880/12921 (84%)]	Loss: 0.365900	Accuracy: 89.10%
# Train Epoch: 7 [11520/12921 (89%)]	Loss: 0.340615	Accuracy: 89.13%
# Train Epoch: 7 [12160/12921 (94%)]	Loss: 0.250234	Accuracy: 89.26%
# Train Epoch: 7 [12800/12921 (99%)]	Loss: 0.336832	Accuracy: 89.18%
# Epoch: 7 Training Accuracy: 89.16%
#
# Test set: Average loss: 0.4195, Accuracy: 3898/4444 (88%)
# Most frequently missed letter: S (Index: 18) with 49 misses
# Train Epoch: 8 [0/12921 (0%)]	Loss: 0.303508	Accuracy: 85.94%
# Train Epoch: 8 [640/12921 (5%)]	Loss: 0.305104	Accuracy: 90.62%
# Train Epoch: 8 [1280/12921 (10%)]	Loss: 0.472270	Accuracy: 89.43%
# Train Epoch: 8 [1920/12921 (15%)]	Loss: 0.243729	Accuracy: 89.67%
# Train Epoch: 8 [2560/12921 (20%)]	Loss: 0.117750	Accuracy: 90.28%
# Train Epoch: 8 [3200/12921 (25%)]	Loss: 0.296258	Accuracy: 90.32%
# Train Epoch: 8 [3840/12921 (30%)]	Loss: 0.455206	Accuracy: 90.22%
# Train Epoch: 8 [4480/12921 (35%)]	Loss: 0.532277	Accuracy: 90.32%
# Train Epoch: 8 [5120/12921 (40%)]	Loss: 0.341062	Accuracy: 90.12%
# Train Epoch: 8 [5760/12921 (45%)]	Loss: 0.241972	Accuracy: 90.25%
# Train Epoch: 8 [6400/12921 (50%)]	Loss: 0.284244	Accuracy: 90.27%
# Train Epoch: 8 [7040/12921 (54%)]	Loss: 0.415342	Accuracy: 90.15%
# Train Epoch: 8 [7680/12921 (59%)]	Loss: 0.332487	Accuracy: 90.16%
# Train Epoch: 8 [8320/12921 (64%)]	Loss: 0.503397	Accuracy: 90.24%
# Train Epoch: 8 [8960/12921 (69%)]	Loss: 0.174889	Accuracy: 90.36%
# Train Epoch: 8 [9600/12921 (74%)]	Loss: 0.623785	Accuracy: 90.31%
# Train Epoch: 8 [10240/12921 (79%)]	Loss: 0.225850	Accuracy: 90.25%
# Train Epoch: 8 [10880/12921 (84%)]	Loss: 0.337379	Accuracy: 90.18%
# Train Epoch: 8 [11520/12921 (89%)]	Loss: 0.448131	Accuracy: 90.19%
# Train Epoch: 8 [12160/12921 (94%)]	Loss: 0.205329	Accuracy: 90.24%
# Train Epoch: 8 [12800/12921 (99%)]	Loss: 0.124997	Accuracy: 90.23%
# Epoch: 8 Training Accuracy: 90.25%
#
# Test set: Average loss: 0.3990, Accuracy: 3933/4444 (89%)
# Most frequently missed letter: S (Index: 18) with 48 misses
# Train Epoch: 9 [0/12921 (0%)]	Loss: 0.246364	Accuracy: 92.19%
# Train Epoch: 9 [640/12921 (5%)]	Loss: 0.326624	Accuracy: 91.90%
# Train Epoch: 9 [1280/12921 (10%)]	Loss: 0.297868	Accuracy: 91.37%
# Train Epoch: 9 [1920/12921 (15%)]	Loss: 0.233411	Accuracy: 91.08%
# Train Epoch: 9 [2560/12921 (20%)]	Loss: 0.151946	Accuracy: 91.73%
# Train Epoch: 9 [3200/12921 (25%)]	Loss: 0.227217	Accuracy: 91.94%
# Train Epoch: 9 [3840/12921 (30%)]	Loss: 0.279306	Accuracy: 92.06%
# Train Epoch: 9 [4480/12921 (35%)]	Loss: 0.219469	Accuracy: 92.21%
# Train Epoch: 9 [5120/12921 (40%)]	Loss: 0.269936	Accuracy: 92.03%
# Train Epoch: 9 [5760/12921 (45%)]	Loss: 0.242352	Accuracy: 92.03%
# Train Epoch: 9 [6400/12921 (50%)]	Loss: 0.165675	Accuracy: 92.08%
# Train Epoch: 9 [7040/12921 (54%)]	Loss: 0.408802	Accuracy: 92.02%
# Train Epoch: 9 [7680/12921 (59%)]	Loss: 0.244386	Accuracy: 91.98%
# Train Epoch: 9 [8320/12921 (64%)]	Loss: 0.318560	Accuracy: 91.97%
# Train Epoch: 9 [8960/12921 (69%)]	Loss: 0.090232	Accuracy: 92.03%
# Train Epoch: 9 [9600/12921 (74%)]	Loss: 0.392752	Accuracy: 91.97%
# Train Epoch: 9 [10240/12921 (79%)]	Loss: 0.209610	Accuracy: 91.96%
# Train Epoch: 9 [10880/12921 (84%)]	Loss: 0.342613	Accuracy: 91.95%
# Train Epoch: 9 [11520/12921 (89%)]	Loss: 0.334480	Accuracy: 92.01%
# Train Epoch: 9 [12160/12921 (94%)]	Loss: 0.259618	Accuracy: 92.06%
# Train Epoch: 9 [12800/12921 (99%)]	Loss: 0.138136	Accuracy: 92.06%
# Epoch: 9 Training Accuracy: 92.05%
#
# Test set: Average loss: 0.3950, Accuracy: 3949/4444 (89%)
# Most frequently missed letter: K (Index: 10) with 43 misses
# Train Epoch: 10 [0/12921 (0%)]	Loss: 0.278262	Accuracy: 92.19%
# Train Epoch: 10 [640/12921 (5%)]	Loss: 0.189060	Accuracy: 93.04%
# Train Epoch: 10 [1280/12921 (10%)]	Loss: 0.361483	Accuracy: 93.30%
# Train Epoch: 10 [1920/12921 (15%)]	Loss: 0.173492	Accuracy: 92.94%
# Train Epoch: 10 [2560/12921 (20%)]	Loss: 0.150184	Accuracy: 92.91%
# Train Epoch: 10 [3200/12921 (25%)]	Loss: 0.164156	Accuracy: 93.01%
# Train Epoch: 10 [3840/12921 (30%)]	Loss: 0.118823	Accuracy: 93.14%
# Train Epoch: 10 [4480/12921 (35%)]	Loss: 0.280101	Accuracy: 93.09%
# Train Epoch: 10 [5120/12921 (40%)]	Loss: 0.309780	Accuracy: 93.02%
# Train Epoch: 10 [5760/12921 (45%)]	Loss: 0.360547	Accuracy: 92.74%
# Train Epoch: 10 [6400/12921 (50%)]	Loss: 0.263481	Accuracy: 92.67%
# Train Epoch: 10 [7040/12921 (54%)]	Loss: 0.146399	Accuracy: 92.79%
# Train Epoch: 10 [7680/12921 (59%)]	Loss: 0.216986	Accuracy: 92.73%
# Train Epoch: 10 [8320/12921 (64%)]	Loss: 0.087658	Accuracy: 92.68%
# Train Epoch: 10 [8960/12921 (69%)]	Loss: 0.300951	Accuracy: 92.66%
# Train Epoch: 10 [9600/12921 (74%)]	Loss: 0.379254	Accuracy: 92.76%
# Train Epoch: 10 [10240/12921 (79%)]	Loss: 0.091538	Accuracy: 92.76%
# Train Epoch: 10 [10880/12921 (84%)]	Loss: 0.176011	Accuracy: 92.72%
# Train Epoch: 10 [11520/12921 (89%)]	Loss: 0.304697	Accuracy: 92.59%
# Train Epoch: 10 [12160/12921 (94%)]	Loss: 0.314074	Accuracy: 92.53%
# Train Epoch: 10 [12800/12921 (99%)]	Loss: 0.160413	Accuracy: 92.56%
# Epoch: 10 Training Accuracy: 92.57%
#
# Test set: Average loss: 0.3844, Accuracy: 3958/4444 (89%)
# Most frequently missed letter: S (Index: 18) with 42 misses
#
# Final Evaluation: Loss: 0.3883, Accuracy: 89.11%, Precision: 0.8902, Recall: 0.8899, F1 Score: 0.8893
